# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

# %%
restaurants=pd.read_csv('zomato.csv',encoding="ISO-8859-1")
countrycode=pd.read_excel('country-code.xlsx')

# %%
restaurants.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
countrycode
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %% [markdown]
# ### 1 Meging the country code sheet and zomato  file to get the country code

# %%
restaurants=restaurants.merge(countrycode,on='Country Code')

# %%
restaurants.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
# let list all the country now and do analysis on each one

indiaRes=restaurants[restaurants['Country']=='India']
singaporeRes=restaurants[restaurants['Country']=='Singapore']
AusRes=restaurants[restaurants['Country']=='Australia']
BrazilRes=restaurants[restaurants['Country']=='Brazil']
CanadaRes=restaurants[restaurants['Country']=='Canada']
UkRes=restaurants[restaurants['Country']=='Uk']
UAERes=restaurants[restaurants['Country']=='UAE']
UnitedStatesRes=restaurants[restaurants['Country']=='USA']
TurkeyRes=restaurants[restaurants['Country']=='Turkey']
NewZealandRes=restaurants[restaurants['Country']=='New Zealand']

# %%
NewZealandRes.City.value_counts()
# Out:
# City
# Auckland           20
# Wellington City    20
# Name: count, dtype: int64

# %%
TurkeyRes.City.value_counts()
# Out:
# City
# Ankara       20
# ÛÁstanbul    14
# Name: count, dtype: int64

# %%
TurkeyRes.head()
# Out:
#       Restaurant ID          Restaurant Name  Country Code    City  \
# 9517        6001980              Timboo Cafe           208  Ankara
# 9518        6000168  Hattena Hatay  SofrasÛ±           208  Ankara
# 9519        6000447  MasabaôÛ± Kebapí_Û±sÛ±           208  Ankara
# 9520        6004408          Turta Home Cafe           208  Ankara
# 9521        6003426                     Liva           208  Ankara
#
#                                                 Address  \
# 9517  Armada AVM, Kat -1, Eskiôehir Yolu, No 6, Yen...
# 9518  Balgat Mahallesi, OsmanlÛ± Caddesi, No 41/A, í...
# 9519  Balgat Mahallesi, Ziyabey Caddesi, No 35, ían...
# 9520  Mutlukent Mahallesi, 1944. Cadde, 1948. Sokak,...
# 9521  íukurambar Mahallesi, Muhsin YazÛ±cÛ±oÛôlu Ca...
#
#                                     Locality  \
# 9517  Armada AVM, Sí_Ûôí_tí_zí_, Yenimahalle
# 9518                                  Balgat
# 9519                                  Balgat
# ...

# %%
UnitedStatesRes.head()
# Out:
# Empty DataFrame
# Columns: [Restaurant ID, Restaurant Name, Country Code, City, Address, Locality, Locality Verbose, Longitude, Latitude, Cuisines, Average Cost for two, Currency, Has Table booking, Has Online delivery, Is delivering now, Switch to order menu, Price range, Aggregate rating, Rating color, Rating text, Votes, Country_x, Country_y, Country]
# Index: []
#
# [0 rows x 24 columns]

# %%
UnitedStatesRes.City.value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
UAERes.head()
# Out:
#      Restaurant ID         Restaurant Name  Country Code       City  \
# 564       18212135                 Denny's           214  Abu Dhabi
# 565        5704255  Famous Dave's Barbecue           214  Abu Dhabi
# 566        5701978          Pizza Di Rocco           214  Abu Dhabi
# 567        5701729          Sofra Istanbul           214  Abu Dhabi
# 568        5704168                    Salt           214  Abu Dhabi
#
#                                                Address  \
# 564  Abu Dhabi Mall, Tourist Club Area (Al Zahiyah)...
# 565  Near The One, Level 3, Abu Dhabi Mall, Tourist...
# 566  Near Corner of Salam and Al Falah Street (9th ...
# 567  Next to ADNOC Petrol Station, Muroor Road, Al ...
# 568         Inside Mushrif Park, Al Mushrif, Abu Dhabi
#
#                                             Locality  \
# 564  Abu Dhabi Mall, Tourist Club Area  (Al Zahiyah)
# 565  Abu Dhabi Mall, Tourist Club Area  (Al Zahiyah)
# 566                                       Al Dhafrah
# ...

# %%
UAERes.City.value_counts()
# Out:
# City
# Abu Dhabi    20
# Dubai        20
# Sharjah      20
# Name: count, dtype: int64

# %%
indiaRes.head()
# Out:
#      Restaurant ID                        Restaurant Name  Country Code  City  \
# 624        3400025                             Jahanpanah             1  Agra
# 625        3400341                    Rangrezz Restaurant             1  Agra
# 626        3400005                Time2Eat - Mama Chicken             1  Agra
# 627        3400021  Chokho Jeeman Marwari Jain Bhojanalya             1  Agra
# 628        3400017                         Pinch Of Spice             1  Agra
#
#                                                Address     Locality  \
# 624  E 23, Shopping Arcade, Sadar Bazaar, Agra Cant...   Agra Cantt
# 625  E-20, Shopping Arcade, Sadar Bazaar, Agra Cant...   Agra Cantt
# 626        Main Market, Sadar Bazaar, Agra Cantt, Agra   Agra Cantt
# 627  1/48, Delhi Gate, Station Road, Raja Mandi, Ci...  Civil Lines
# 628  23/453, Opposite Sanjay Cinema, Wazipura Road,...  Civil Lines
#
#       Locality Verbose  Longitude   Latitude                        Cuisines  \
# ...

# %%
#Finding the number of restaurants according to cities
indiaRes.City.value_counts()
# Out:
# City
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
# Ahmedabad         21
# Guwahati          21
# Lucknow           21
# Bhubaneshwar      21
# Amritsar          21
# Pune              20
# Puducherry        20
# Patna             20
# Ludhiana          20
# Ranchi            20
# Surat             20
# Vadodara          20
# Nashik            20
# Nagpur            20
# Mysore            20
# Mumbai            20
# Varanasi          20
# Mangalore         20
# Agra              20
# Kochi             20
# Kolkata           20
# Dehradun          20
# Allahabad         20
# Aurangabad        20
# Bangalore         20
# Bhopal            20
# Chennai           20
# Coimbatore        20
# Goa               20
# Indore            20
# Jaipur            20
# Kanpur            20
# Vizag             20
# Chandigarh        18
# Hyderabad         18
# Secunderabad       2
# Panchkula          1
# Mohali             1
# ...

# %%
#Top restaurants in delhi based on the rating and and vote count

DelhiTopRes = indiaRes[(indiaRes['City'] == 'New Delhi') & (indiaRes['Aggregate rating'] > 4.5)][['Aggregate rating', 'Restaurant Name', 'Votes']].sort_values(ascending=False, by='Votes')

# %%
DelhiTopRes.style.apply(lambda x:['background: green' if x.name=='Votes' else 'background: lightsteelblue' for i in x])
# Out:
# <style type="text/css">
# #T_730b9_row0_col0, #T_730b9_row0_col1, #T_730b9_row1_col0, #T_730b9_row1_col1, #T_730b9_row2_col0, #T_730b9_row2_col1, #T_730b9_row3_col0, #T_730b9_row3_col1, #T_730b9_row4_col0, #T_730b9_row4_col1, #T_730b9_row5_col0, #T_730b9_row5_col1, #T_730b9_row6_col0, #T_730b9_row6_col1, #T_730b9_row7_col0, #T_730b9_row7_col1, #T_730b9_row8_col0, #T_730b9_row8_col1, #T_730b9_row9_col0, #T_730b9_row9_col1, #T_730b9_row10_col0, #T_730b9_row10_col1, #T_730b9_row11_col0, #T_730b9_row11_col1, #T_730b9_row12_col0, #T_730b9_row12_col1, #T_730b9_row13_col0, #T_730b9_row13_col1, #T_730b9_row14_col0, #T_730b9_row14_col1, #T_730b9_row15_col0, #T_730b9_row15_col1, #T_730b9_row16_col0, #T_730b9_row16_col1 {
#   background: lightsteelblue;
# }
# ...

# %%
singaporeRes.head()
# Out:
#      Restaurant ID       Restaurant Name  Country Code       City  \
# 544       18483372             Sky On 57           184  Singapore
# 545       18484349  Cut By Wolfgang Puck           184  Singapore
# 546       18496057      Restaurant Andre           184  Singapore
# 547       18483389      Potato Head Folk           184  Singapore
# 548       18483222                  Jaan           184  Singapore
#
#                                               Address  \
# 544    10 Bayfront Avenue, 57 Marina Bay Sands 018956
# 545  2 Bayfront Avenue, B1-71 Marina Bay Sands 018972
# 546                        41 Bukit Pasoh Road 089855
# 547                         36 Keong Saik Road 089143
# 548  2 Stamford Road, Level 70 Equinox Complex 178882
#
#                             Locality  \
# 544   Bayfront Avenue, Downtown Core
# 545  Bayfront Subzone, Downtown Core
# 546          Cantonment Road, Outram
# 547                Chinatown, Outram
# 548         City Hall, Downtown Core
#
# ...

# %%
singaporeRes.City.value_counts()
# Out:
# City
# Singapore    20
# Name: count, dtype: int64

# %%
SingaporeTopRes = singaporeRes[(singaporeRes['City'] == 'Singapore') & (singaporeRes['Aggregate rating'] > 4)][['Aggregate rating', 'Restaurant Name', 'Votes']].sort_values(ascending=False, by='Votes')

# %%
SingaporeTopRes.style.apply(lambda x:['background: green' if x.name=='Votes' else 'background: lightsteelblue' for i in x])
# Out:
# <style type="text/css">
# #T_4c697_row0_col0, #T_4c697_row0_col1, #T_4c697_row1_col0, #T_4c697_row1_col1 {
#   background: lightsteelblue;
# }
# #T_4c697_row0_col2, #T_4c697_row1_col2 {
#   background: green;
# }
# </style>
# <table id="T_4c697">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4c697_level0_col0" class="col_heading level0 col0" >Aggregate rating</th>
#       <th id="T_4c697_level0_col1" class="col_heading level0 col1" >Restaurant Name</th>
#       <th id="T_4c697_level0_col2" class="col_heading level0 col2" >Votes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c697_level0_row0" class="row_heading level0 row0" >551</th>
#       <td id="T_4c697_row0_col0" class="data row0 col0" >4.100000</td>
#       <td id="T_4c697_row0_col1" class="data row0 col1" >Fratini La Trattoria</td>
#       <td id="T_4c697_row0_col2" class="data row0 col2" >35</td>
#     </tr>
#     <tr>
# ...

# %%
UkRes.City.value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
UkRes.head()
# Out:
# Empty DataFrame
# Columns: [Restaurant ID, Restaurant Name, Country Code, City, Address, Locality, Locality Verbose, Longitude, Latitude, Cuisines, Average Cost for two, Currency, Has Table booking, Has Online delivery, Is delivering now, Switch to order menu, Price range, Aggregate rating, Rating color, Rating text, Votes, Country]
# Index: []
#
# [0 rows x 22 columns]

# %%
AusRes.City.value_counts()
# Out:
# City
# Hepburn Springs    2
# Armidale           1
# Macedon            1
# Trentham East      1
# Tanunda            1
# Phillip Island     1
# Penola             1
# Paynesville        1
# Palm Cove          1
# Montville          1
# Middleton Beach    1
# Mayfield           1
# Lorn               1
# Balingup           1
# Lakes Entrance     1
# Inverloch          1
# Huskisson          1
# Forrest            1
# Flaxton            1
# East Ballina       1
# Dicky Beach        1
# Beechworth         1
# Victor Harbor      1
# Name: count, dtype: int64

# %%
SingaporeTopRes = singaporeRes[(singaporeRes['City'] == 'Singapore') & (singaporeRes['Aggregate rating'] > 4)][['Aggregate rating', 'Restaurant Name', 'Votes']].sort_values(ascending=False, by='Votes')

# %% [markdown]
# ### Finding the relationship b/w the rating and votes

# %%
import seaborn as sns

# Joint plot is Data Visualisation tool used to show the relationship b/w two variables with their individual Distribution
sns.jointplot(x='Votes',y='Aggregate rating', data=DelhiTopRes)

# %% [markdown]
# ### 4. No of Restaurants in each country

# %%
India=indiaRes['Restaurant Name'].nunique()
India
# Out:
# 6604

# %%
Australia=AusRes['Restaurant Name'].nunique()
Australia
# Out:
# 24

# %%
Singapore=singaporeRes['Restaurant Name'].nunique()
Singapore
# Out:
# 20

# %%
Brazil=BrazilRes['Restaurant Name'].nunique()
Brazil
# Out:
# 58

# %%
UK=UkRes['Restaurant Name'].nunique()
UK
# Out:
# 0

# %%
Canada=CanadaRes['Restaurant Name'].nunique()
Canada
# Out:
# 4

# %% [markdown]
# ### Top 5 restaurants with online delivery

# %%
DelhiTopResOnline = indiaRes[(indiaRes['City'] == 'New Delhi') & (indiaRes['Aggregate rating'] > 4.5) & (indiaRes['Has Online delivery']=='Yes')][['Aggregate rating', 'Restaurant Name', 'Votes','Has Online delivery']].sort_values(ascending=False, by='Votes')

# %%
DelhiTopResOnline.style.apply(lambda x:['background: green' if x.name=='Has Online delivery' else 'background: lightsteelblue' for i in x])
# Out:
# <style type="text/css">
# #T_618fd_row0_col0, #T_618fd_row0_col1, #T_618fd_row0_col2, #T_618fd_row1_col0, #T_618fd_row1_col1, #T_618fd_row1_col2, #T_618fd_row2_col0, #T_618fd_row2_col1, #T_618fd_row2_col2, #T_618fd_row3_col0, #T_618fd_row3_col1, #T_618fd_row3_col2, #T_618fd_row4_col0, #T_618fd_row4_col1, #T_618fd_row4_col2, #T_618fd_row5_col0, #T_618fd_row5_col1, #T_618fd_row5_col2 {
#   background: lightsteelblue;
# }
# #T_618fd_row0_col3, #T_618fd_row1_col3, #T_618fd_row2_col3, #T_618fd_row3_col3, #T_618fd_row4_col3, #T_618fd_row5_col3 {
#   background: green;
# }
# </style>
# <table id="T_618fd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_618fd_level0_col0" class="col_heading level0 col0" >Aggregate rating</th>
#       <th id="T_618fd_level0_col1" class="col_heading level0 col1" >Restaurant Name</th>
#       <th id="T_618fd_level0_col2" class="col_heading level0 col2" >Votes</th>
# ...

# %%
AgraTopResOnline = indiaRes[(indiaRes['City'] == 'Agra') & (indiaRes['Aggregate rating'] > 1) & (indiaRes['Has Online delivery']=='Yes')][['Aggregate rating', 'Restaurant Name', 'Votes','Has Online delivery']].sort_values(ascending=False, by='Votes')

# %%
AgraTopResOnline.style.apply(lambda x:['background: green' if x.name=='Has Online delivery' else 'background: lightsteelblue' for i in x])
# Out:
# <style type="text/css">
# </style>
# <table id="T_629d0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_629d0_level0_col0" class="col_heading level0 col0" >Aggregate rating</th>
#       <th id="T_629d0_level0_col1" class="col_heading level0 col1" >Restaurant Name</th>
#       <th id="T_629d0_level0_col2" class="col_heading level0 col2" >Votes</th>
#       <th id="T_629d0_level0_col3" class="col_heading level0 col3" >Has Online delivery</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
NoidaTopResOnline = indiaRes[(indiaRes['City'] == 'Noida') & (indiaRes['Aggregate rating'] > 4) & (indiaRes['Has Online delivery']=='Yes')][['Aggregate rating', 'Restaurant Name', 'Votes','Has Online delivery']].sort_values(ascending=False, by='Votes')

# %%
NoidaTopResOnline.style.apply(lambda x:['background: green' if x.name=='Has Online delivery' else 'background: lightsteelblue' for i in x])
# Out:
# <style type="text/css">
# ...

# %%
GurgaonTopResOnline=indiaRes[(indiaRes['City']=='Gurgaon')&(indiaRes['Aggregate rating']>4)&(indiaRes['Has Online delivery']=='Yes')][['Aggregate rating', 'Restaurant Name', 'Votes','Has Online delivery']].sort_values(ascending=False, by='Votes')

# %%
GurgaonTopResOnline.style.apply(lambda x:['background: green' if x.name=='Has Online delivery' else 'background: lightsteelblue' for i in x])
# Out:
# <style type="text/css">
# ...

# %%
Delhi=indiaRes[(indiaRes['City']=='Delhi')&(indiaRes['Aggregate Rating']>4.5)&(indiaRes['Vote']>500)][['Average Cost for two','Aggregate Rating','Restaurant Name', 'Votes','Has Online delivery']].sort_values(by='Votes', ascending=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Aggregate Rating'
#
# The above exception was the direct cause of the following exception:
#
# ...
